# %% [markdown]
# # About Python

# %% [markdown]
# ## Overview

# %% [markdown]
# - Reference :
# [Quantiative Economics] (http://quant-econ.net/py/learning_python.html, "Programming in Python")
# - [PyVideo.Org] (http://pyvideo.org/)

# %% [markdown]
# ## Simple Examples with Numpy and SciPy

# %%
import numpy as np
a = np.linspace(-np.pi, np.pi, 100)
b = np.cos(a)
c = np.ones(25)
np.dot(c,c)
# Out:
# 25.0

# %% [markdown]
# Calculation of $\int_{-2}^2\phi(z)dz$, where $\phi$ is the standard normal density

# %%
from scipy.stats import norm
from scipy.integrate import quad
phi = norm()
value, error = quad(phi.pdf,-2, 2)
value
# Out:
# 0.9544997361036417

# %% [markdown]
# ## A Graphics Example

# %% [markdown]
# - Related reference 1 : [Matplotlib thumbnail gallery](http://matplotlib.org/gallery.html)
# - Related reference 2 : [VPython](http://www.vpython.org/)
# - Related reference 3 : [pyprocessing](https://code.google.com/p/pyprocessing/)

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


# example data
mu = 100 # mean of distribution
sigma = 15 # standard deviation of distribution
x = mu + sigma * np.random.randn(10000)

num_bins = 50
# the histogram of the data
n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor='green', alpha=0.5)
# add a 'best fit' line
y = mlab.normpdf(bins, mu, sigma)
plt.plot(bins, y, 'r--')
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title(r'Histogram of IQ: $\mu=100$, $\sigma=15$')

# Tweak spacing to prevent clipping of ylabel
# plt.subplots_adjust(left=0.15)
#plt.show()

# %% [markdown]
# ## Symbolic Algebra

# %%
from sympy import Symbol
x, y = Symbol('x'), Symbol('y')  # Treat 'x' and 'y' as algebraic symbols
x + x + x + y
# Out:
# 3*x + y

# %%
expression = (x + y)**2
expression.expand()
# Out:
# x**2 + 2*x*y + y**2

# %%
from sympy import solve
solve(x**2 + x + 2)
# Out:
# [-1/2 - sqrt(7)*I/2, -1/2 + sqrt(7)*I/2]

# %%
from sympy import limit, sin, diff
[limit(1 / x, x, 0), limit(sin(x) / x, x, 0), diff(sin(x), x)]
# Out:
# [oo, 1, cos(x)]

# %% [markdown]
# ## Statistical Manipulation with Pandas

# %%
import pandas as pd
import scipy as sp

data = sp.randn(5, 2)  # Create 5x2 matrix of random numbers for toy example
dates = pd.date_range('28/12/2010', periods=5)

df = pd.DataFrame(data, columns=('price', 'weight'), index=dates)
print df
df.mean()
# Out:
#                price    weight
# 2010-12-28 -0.751989 -0.722105
# 2010-12-29  0.025107 -0.424566
# 2010-12-30 -0.107648  0.614274
# 2010-12-31 -0.684521 -1.186422
# 2011-01-01  0.966866 -1.059773
# price    -0.110437
# weight   -0.555719
# dtype: float64

# %% [markdown]
# - Related reference 1 : [statsmodels](http://statsmodels.sourceforge.net/)
# - Related reference 2 : [scikit-learn](http://scikit-learn.org/stable/)
# - Related reference 3 : [pyMC](http://pymc-devs.github.io/pymc/) and [pystan](https://pystan.readthedocs.org/en/latest/)

# %% [markdown]
# ## Networks and Graphs

# %% [markdown]
# - Related reference : [NetworkX](http://networkx.github.io/)

# %%
"""
Filename: nx_demo.py
Authors: John Stachurski and Thomas J. Sargent
"""

"""
An example code that generates and plots a random graph, 
with node color determined by shortest path length from a central node
"""

import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

G = nx.random_geometric_graph(200, 0.12)  # Generate random graph
pos = nx.get_node_attributes(G, 'pos')    # Get positions of nodes
# find node nearest the center point (0.5,0.5)
dists = [(x - 0.5)**2 + (y - 0.5)**2 for x, y in list(pos.values())]
ncenter = np.argmin(dists)
# Plot graph, coloring by path length from central node
p = nx.single_source_shortest_path_length(G, ncenter)
plt.figure()
nx.draw_networkx_edges(G, pos, alpha=0.4)
nx.draw_networkx_nodes(G, pos, nodelist=list(p.keys()),
                       node_size=120, alpha=0.5,
                       node_color=list(p.values()), cmap=plt.cm.jet_r)
plt.show()

# %%
"""
Random graph from given degree sequence.
Draw degree rank plot and graph with matplotlib.
"""
__author__ = """Aric Hagberg <aric.hagberg@gmail.com>"""
import networkx as nx
import matplotlib.pyplot as plt
G = nx.gnp_random_graph(100,0.02)

degree_sequence=sorted(nx.degree(G).values(),reverse=True) # degree sequence
#print "Degree sequence", degree_sequence
dmax=max(degree_sequence)

plt.loglog(degree_sequence,'b-',marker='o')
plt.title("Degree rank plot")
plt.ylabel("degree")
plt.xlabel("rank")

# draw graph in inset
plt.axes([0.45,0.45,0.45,0.45])
Gcc=sorted(nx.connected_component_subgraphs(G), key = len, reverse=True)[0]
pos=nx.spring_layout(Gcc)
plt.axis('off')
nx.draw_networkx_nodes(Gcc,pos,node_size=20)
nx.draw_networkx_edges(Gcc,pos,alpha=0.4)

plt.savefig("degree_histogram.png")
plt.show()
